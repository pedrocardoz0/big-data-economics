# %% [markdown]
# # ***Análises Econômicas*** 📊
#
# Nosso objetivo é aprofundar a compreensão desses indicadores vitais, explorando seu impacto, tendências e inter-relações, fornecendo insights para a compreensão do panorama econômico. Vamos explorar dados, tendências e padrões para criar uma análise abrangente e informada desses elementos-chave que moldam nossa realidade econômica.
#
# ![economics-image.jpg](data:image/jpeg;base64,...)

# %%
# !pip install fredapi

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import time
from google.colab import userdata
from fredapi import Fred

plt.style.use('fivethirtyeight')
pd.set_option('display.max_columns', 500)
color_pallet = plt.rcParams["axes.prop_cycle"].by_key()["color"]

fred_key = userdata.get('fre-api')

# %%
fred = Fred(api_key=fred_key)

# %% [markdown]
# ## Busca pelas taxas de desemprego de outros paises.

# %%
unemp_df = fred.search('unemployment rate', filter=('frequency', 'Annual'))
unemp_df.query('units == "Percent"')
unemp_df = unemp_df.loc[unemp_df['title'].str.contains('Unemployment Rate: Aged 15 and over: All Persons for ')]
unemp_df = unemp_df.loc[unemp_df['seasonal_adjustment_short'].str.contains('N')]
unemp_df
# Out:
#                               id realtime_start realtime_end  \
# series id
# LRUNTTTTCAA156N  LRUNTTTTCAA156N     2023-11-20   2023-11-20
# LRUNTTTTAUA156N  LRUNTTTTAUA156N     2023-11-20   2023-11-20
# LRUNTTTTKRA156N  LRUNTTTTKRA156N     2023-11-20   2023-11-20
# LRUNTTTTDEA156N  LRUNTTTTDEA156N     2023-11-20   2023-11-20
# LRUNTTTTBRA156N  LRUNTTTTBRA156N     2023-11-20   2023-11-20
# LRUNTTTTMXA156N  LRUNTTTTMXA156N     2023-11-20   2023-11-20
# LRUNTTTTNZA156N  LRUNTTTTNZA156N     2023-11-20   2023-11-20
# LRUNTTTTIDA156N  LRUNTTTTIDA156N     2023-11-20   2023-11-20
# LRUNTTTTCLA156N  LRUNTTTTCLA156N     2023-11-20   2023-11-20
# LRUNTTTTGBA156N  LRUNTTTTGBA156N     2023-11-20   2023-11-20
# LRUNTTTTFRA156N  LRUNTTTTFRA156N     2023-11-20   2023-11-20
# LRUNTTTTJPA156N  LRUNTTTTJPA156N     2023-11-20   2023-11-20
# LRUNTTTTILA156N  LRUNTTTTILA156N     2023-11-20   2023-11-20
# LRUNTTTTUSA156N  LRUNTTTTUSA156N     2023-11-20   2023-11-20
# ...

# %%
all_datasets = []

for myid in unemp_df.index:
    results = fred.get_series(myid)
    results = results.to_frame(name=myid)
    all_datasets.append(results)
    time.sleep(0.1)


uemp_results = pd.concat(all_datasets, axis=1)

# %% [markdown]
# ## Ajuste no nome da coluna de cada pais

# %%
uemp_copy = uemp_results.copy()

id_to_country = unemp_df['title'].str.replace('Unemployment Rate: Aged 15 and over: All Persons for ','').to_dict()
uemp_copy.columns = [id_to_country[c] for c in uemp_copy.columns]

# %% [markdown]
# ## Visualização da taxa de desemprego de cada pais

# %%
px.line(uemp_copy)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Busca pelo gasto público de cada país.

# %%
inflation_df = fred.search('inflation rate nation', filter=('frequency', 'Annual'))
inflation_df.query('units == "Percent"')
inflation_df = inflation_df.loc[inflation_df['title'].str.contains('Consumer Price Index: OECD Groups: All Items Non-Food Non-Energy: Total for ')]
inflation_df
# Out:
#                               id realtime_start realtime_end  \
# series id
# CPGRLE01JPA657N  CPGRLE01JPA657N     2023-11-20   2023-11-20
# CPGRLE01GBA657N  CPGRLE01GBA657N     2023-11-20   2023-11-20
# CPGRLE01DEA657N  CPGRLE01DEA657N     2023-11-20   2023-11-20
# CPGRLE01CAA657N  CPGRLE01CAA657N     2023-11-20   2023-11-20
# CPGRLE01AUA657N  CPGRLE01AUA657N     2023-11-20   2023-11-20
# ...                          ...            ...          ...
# CPGRLE01GRA659N  CPGRLE01GRA659N     2023-11-20   2023-11-20
# CPGRLE01EEA659N  CPGRLE01EEA659N     2023-11-20   2023-11-20
# CPGRLE01LUA659N  CPGRLE01LUA659N     2023-11-20   2023-11-20
# CPGRLE01PTA659N  CPGRLE01PTA659N     2023-11-20   2023-11-20
# CPGRLE01SIA659N  CPGRLE01SIA659N     2023-11-20   2023-11-20
#
#                                                              title  \
# series id
# CPGRLE01JPA657N  Consumer Price Index: OECD Groups: All Items N...
# CPGRLE01GBA657N  Consumer Price Index: OECD Groups: All Items N...
# ...

# %%
all_inflation_datasets = []

for myid in inflation_df.index:
    results = fred.get_series(myid)
    results = results.to_frame(name=myid)
    all_inflation_datasets.append(results)
    time.sleep(0.1)


inflation_results = pd.concat(all_inflation_datasets, axis=1)

# %% [markdown]
# ## Ajuste no nome da coluna de cada pais.

# %%
inflation_copy = inflation_results.copy()

id_to_country = inflation_df['title'].str.replace('Consumer Price Index: OECD Groups: All Items Non-Food Non-Energy: Total for ','').to_dict()
inflation_df = inflation_df.loc[inflation_df['seasonal_adjustment_short'].str.contains('N')]
inflation_copy.columns = [id_to_country[c] for c in inflation_copy.columns]
inflation_copy = inflation_copy.loc[:, ~inflation_copy.columns.duplicated()]

# %% [markdown]
# ## Visualizando a inflação de cada pais

# %%
px.line(inflation_copy)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Visualizando a Inflação e Taxa de Desemprego.

# %%
country = 'United States'
fig, ax = plt.subplots(figsize=(10, 5), sharex=True)
ax2 = ax.twinx()
uemp_copy_2, inflation_copy_2 = uemp_copy, inflation_copy
l1 = uemp_copy_2[country] \
    .plot(ax=ax, label='Unemployment')
l2 = inflation_copy_2[country] \
    .plot(ax=ax2, label='Inflation', color=color_pallet[1])

ax2.grid(False)
ax.set_title(country)
fig.legend(labels=['Unemployment', 'Inflation'])
plt.show()

# %%
fig, axs = plt.subplots(10, 5, figsize=(30, 30), sharex=True)
axs = axs.flatten()

i = 0
for country in uemp_copy_2.columns:
    if country in ["Brazil", "Indonesia", "Russia"]:
      continue
    ax2 = axs[i].twinx()
    uemp_copy_2[country] \
        .plot(ax=axs[i], label='Unemployment')
    inflation_copy_2[country] \
        .plot(ax=ax2, label='Inflation', color=color_pallet[1])
    ax2.grid(False)
    axs[i].set_title(country)
    i += 1
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Linear Regression**

# %% [markdown]
# ## Realizando Regressão Linear nos dados dos USA.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt


X = uemp_copy['United States'].drop(index='1955-01-01')
y = inflation_copy['United States']

plt.scatter(X, y)
plt.xlabel('USA Unenployment Rate')
plt.ylabel('USA Inflation Rate')
# Out:
# Text(0, 0.5, 'USA Inflation Rate')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=23)

# %%
X_train = np.array(X_train).reshape(-1, 1)
X_test = np.array(X_test).reshape(-1, 1)

y_train = np.array(y_train).reshape(-1, 1)
y_test = np.array(y_test).reshape(-1, 1)

imputer = SimpleImputer(strategy='mean')
X_train = imputer.fit_transform(X_train)
y_train = imputer.fit_transform(y_train)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
c = lr.intercept_
m = lr.coef_
print(m)
print(c)
y_pred = m * X_train + c
y_pred.flatten()
# Out:
# [[0.48369293]]
# [0.73678347]
# array([3.4132177 , 3.51958536, 3.63491029, 2.56675507, 3.53011016,
#        3.71955656, 2.91743244, 3.67118726, 2.50226267, 4.07426471,
#        3.51958536, 4.36851124, 2.66752443, 3.09075574, 3.28423292,
#        4.8320503 , 3.29632524, 3.61878719, 3.13106349, 2.96983251,
#        3.33260221, 3.51958536, 3.96946457, 4.1548802 , 2.59497049,
#        3.51958536, 3.18749433, 2.62318591, 2.51032422, 3.41724847,
#        2.96983251, 4.41284976, 5.43263569, 3.44949467, 5.38829718,
#        2.47001648, 3.02626335, 3.73164888, 5.38829718, 3.35678686])

# %%
y_pred_train = lr.predict(X_train)
y_pred_train.flatten()
# Out:
# array([3.4132177 , 3.51958536, 3.63491029, 2.56675507, 3.53011016,
#        3.71955656, 2.91743244, 3.67118726, 2.50226267, 4.07426471,
#        3.51958536, 4.36851124, 2.66752443, 3.09075574, 3.28423292,
#        4.8320503 , 3.29632524, 3.61878719, 3.13106349, 2.96983251,
#        3.33260221, 3.51958536, 3.96946457, 4.1548802 , 2.59497049,
#        3.51958536, 3.18749433, 2.62318591, 2.51032422, 3.41724847,
#        2.96983251, 4.41284976, 5.43263569, 3.44949467, 5.38829718,
#        2.47001648, 3.02626335, 3.73164888, 5.38829718, 3.35678686])

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, y_pred_train, color='red')
plt.xlabel('USA Unenployment Rate')
plt.ylabel('USA Inflation Rate')
# Out:
# Text(0, 0.5, 'USA Inflation Rate')

# %%
from sklearn.metrics import r2_score
r2_score(y_train, y_pred_train)
# Out:
# 0.13116733862184649
